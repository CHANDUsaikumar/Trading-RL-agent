# %% [markdown]
# # EDA and Feature Engineering
# This notebook is a starter for exploring price data and creating features for RL agents.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Example: replace with your CSV path
# df = pd.read_csv('../data/raw/example.csv')
# df.head()
